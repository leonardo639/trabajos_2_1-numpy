# %%
import numpy as np 
import matplotlib.pyplot as plt

aleatorios = np.random.default_rng()
x = aleatorios.normal(size=(10, 10))
y = 3 * x + aleatorios.normal(size=(10, 10)) +1

#Diagrama de dispersion(imagen)
fig, ax = plt.subplots(figsize=(6,6))

ax.scatter(x,y)

plt.show()
